# %% [markdown]
# # 🧄 EfficientNetB4 + MS-CAF v2: Multi-Scale Channel-Attention Fusion
#
# **Đề tài:** Phân loại tỏi (Garlic Classification)
#
# ## Architecture (Novel Contributions):
#
# 1. **TRUE Multi-Scale Feature Extraction**
#    - Block5 output (24×24×160): local textures, small defects, edge patterns
#    - Block7 output (12×12×1792): global semantic, color distribution, overall shape
#
# 2. **SE Attention on Spatial Maps** (applied BEFORE GAP — meaningful spatial recalibration)
#
# 3. **Scale-Aware Fusion Gate**: content-dependent learnable weighting of scales
#
# 4. **CB Focal Loss**: Class-Balanced + Focal for imbalanced data
#
# ## Fixes vs v1 (broken version):
# - ❌ v1: Custom `train_step` → Keras couldn't track `val_loss` → always 0.3333 → EarlyStopping restored epoch 1
# - ✅ v2: Standard Functional API + `model.compile(loss=...)` → loss tracking works correctly
# - ❌ v1: "Multi-scale" was fake (GAP vs GMP on same map)
# - ✅ v2: TRUE multi-scale from different backbone blocks
# - ❌ v1: SE applied on (1,1,C) vectors (pointless)
# - ✅ v2: SE applied on (H,W,C) spatial feature maps (meaningful)

# %%
# ============================================================================
# CELL 1: IMPORTS & ENVIRONMENT SETUP
# ============================================================================
# Notebook này chạy ĐỘC LẬP — không phụ thuộc file nào khác.
# ============================================================================

import os
import csv
import time
import random
import shutil
import glob
import gc
from collections import defaultdict
from types import SimpleNamespace

# --- Scientific Computing ---
import numpy as np
import pandas as pd

# --- Visualization ---
import matplotlib.pyplot as plt
import seaborn as sns

# --- Deep Learning Framework ---
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.layers import (
    Dense, GlobalAveragePooling2D, Dropout, BatchNormalization,
    Conv2D, Layer, Input, Concatenate, GlobalMaxPooling2D,
    Reshape, Multiply, Add, Activation,
)
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, CSVLogger, Callback,
)
from tensorflow.keras.regularizers import l2

# --- Scikit-learn Metrics & Utilities ---
from sklearn.utils import class_weight
from sklearn.metrics import (
    classification_report, confusion_matrix,
    roc_curve, auc, roc_auc_score, cohen_kappa_score, matthews_corrcoef,
    balanced_accuracy_score,
)
from sklearn.preprocessing import label_binarize
from sklearn.manifold import TSNE

# ============================================================================
# GPU CONFIGURATION + MIXED PRECISION
# ============================================================================
print("=" * 60)
print("  ENVIRONMENT SETUP — MS-CAF v2 (Fixed)")
print("=" * 60)
print(f"  TensorFlow version : {tf.__version__}")

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"  GPU(s) detected    : {len(gpus)} — {[g.name for g in gpus]}")
else:
    print("  ⚠️  No GPU detected — training will be slow!")

tf.keras.mixed_precision.set_global_policy("mixed_float16")
print(f"  Mixed Precision    : mixed_float16")
print(f"  XLA JIT            : Enabled")
print("=" * 60)
# Out:
# 2026-05-19 12:08:56.959003: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779192537.442916      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779192537.547271      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779192538.536227      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779192538.536296      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779192538.536300      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779192538.536303      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ============================================================
#   ENVIRONMENT SETUP — MS-CAF v2 (Fixed)
# ============================================================
#   TensorFlow version : 2.19.0
#   GPU(s) detected    : 2 — ['/physical_device:GPU:0', '/physical_device:GPU:1']
#   Mixed Precision    : mixed_float16
#   XLA JIT            : Enabled
# ============================================================

# %%
# ============================================================================
# CELL 2: CONFIGURATION & HYPERPARAMETERS
# ============================================================================

# --- Experiment Identification ---
STRATEGY_KEY   = "ms_caf_v2"
STRATEGY_LABEL = "EfficientNetB4 + MS-CAF v2 (Multi-Scale Channel-Attention Fusion)"

# --- Data Paths ---
DATA_DIR        = "/kaggle/input/datasets/giaphuc/dataset-0803/dataset_split_0803"
BASE_RESULT_DIR = f"/kaggle/working/report_EfficientNetB4/{STRATEGY_KEY}"
os.makedirs(BASE_RESULT_DIR, exist_ok=True)

# --- Model Architecture ---
INPUT_SHAPE     = (380, 380, 3)       # EfficientNetB4 standard
BATCH_SIZE      = 32                   # Tăng lại 32 (không cần SupCon memory)
EPOCHS          = 36
LR              = 8e-5                 # Initial learning rate (CosineDecay)
UNFREEZE_BLOCKS = [2, 3, 4, 5, 6, 7]     # Fine-tune top blocks
DROPOUT_RATE    = 0.25                  # Moderate dropout
PATIENCE        = 14                   # EarlyStopping patience

# --- Optimization knobs (tuning for >=0.94) ---
WEIGHT_DECAY    = 1e-5                 # AdamW decoupled weight decay
LABEL_SMOOTHING = 0.03                 # Light smoothing to reduce over-confidence
TTA_ROUNDS      = 4                    # Test-time augmentation rounds

# --- MS-CAF Specific ---
FEAT_DIM        = 256                  # Fusion output dimension
SE_REDUCTION    = 8                    # SE block reduction ratio

# --- Loss ---
FOCAL_GAMMA     = 2.0                  # Focal loss focusing parameter

# --- Reproducibility ---
N_RUNS       = 3
RANDOM_SEEDS = [42, 123, 456]
AUTOTUNE     = tf.data.AUTOTUNE
tf.config.optimizer.set_jit(True)

all_runs_results = []

# --- Print Summary ---
print("=" * 60)
print("  EXPERIMENT CONFIGURATION")
print("=" * 60)
print(f"  Strategy    : {STRATEGY_LABEL}")
print(f"  Dataset     : {DATA_DIR.split('/')[-1]}")
print(f"  Input Shape : {INPUT_SHAPE}")
print(f"  Batch Size  : {BATCH_SIZE}")
print(f"  Epochs      : {EPOCHS} (patience={PATIENCE})")
print(f"  LR          : {LR} (CosineDecay → 1e-6)")
print(f"  Optimizer   : AdamW (wd={WEIGHT_DECAY}, clipnorm=1.0)")
print(f"  Label smooth: {LABEL_SMOOTHING}")
print(f"  TTA rounds  : {TTA_ROUNDS}")
print(f"  Unfreeze    : blocks {UNFREEZE_BLOCKS}")
print(f"  Runs        : {N_RUNS} × seeds {RANDOM_SEEDS}")
print("-" * 60)
print(f"  [Novel 1] TRUE Multi-Scale: block5(24×24×160) + block7(12×12×1792)")
print(f"  [Novel 2] SE Attention on spatial maps (before GAP)")
print(f"  [Novel 3] Scale-Aware Fusion Gate (content-dependent weighting)")
print(f"  [Loss]    CB Focal (γ={FOCAL_GAMMA}, β=0.9999)")
print("=" * 60)
# Out:
# ============================================================
#   EXPERIMENT CONFIGURATION
# ============================================================
#   Strategy    : EfficientNetB4 + MS-CAF v2 (Multi-Scale Channel-Attention Fusion)
#   Dataset     : dataset_split_0803
#   Input Shape : (380, 380, 3)
#   Batch Size  : 32
#   Epochs      : 30 (patience=12)
#   LR          : 0.0001 (CosineDecay → 1e-6)
#   Unfreeze    : blocks [3, 4, 5, 6, 7]
#   Runs        : 3 × seeds [42, 123, 456]
# ------------------------------------------------------------
#   [Novel 1] TRUE Multi-Scale: block5(24×24×160) + block7(12×12×1792)
#   [Novel 2] SE Attention on spatial maps (before GAP)
#   [Novel 3] Scale-Aware Fusion Gate (content-dependent weighting)
#   [Loss]    CB Focal (γ=2.0, β=0.9999)
# ============================================================

# %%
# ============================================================================
# CELL 3: MS-CAF MODEL ARCHITECTURE (v2 — Keras 3 Compatible)
# ============================================================================
# All ops inside Functional API must use keras.ops or custom Layers.
# No tf.cast, tf.reshape, tf.reduce_mean directly on KerasTensors!
# ============================================================================

import keras.ops as ops


def build_backbone_multiscale(input_shape):
    """Build EfficientNetB4 with 2 outputs: block5 (local) + block7 (semantic)."""
    base = EfficientNetB4(weights='imagenet', include_top=False, input_shape=input_shape)

    block5_layer = None
    for layer in base.layers:
        if 'block5' in layer.name and 'add' in layer.name:
            block5_layer = layer

    if block5_layer is None:
        for layer in base.layers:
            if 'block5' in layer.name and 'project_bn' in layer.name:
                block5_layer = layer
    if block5_layer is None:
        for layer in base.layers:
            if 'block4' in layer.name and 'add' in layer.name:
                block5_layer = layer

    print(f"  Multi-scale outputs:")
    print(f"    Local  : {block5_layer.name} → {block5_layer.output.shape}")
    print(f"    Semantic: final output → {base.output.shape}")

    multi_model = Model(
        inputs=base.input,
        outputs=[block5_layer.output, base.output],
        name='efficientnetb4_multiscale'
    )
    return multi_model, base


class SEAttention(Layer):
    """Squeeze-and-Excitation on spatial feature maps.
    
    All ops use keras.ops (Keras 3 compatible).
    """
    def __init__(self, reduction=8, **kwargs):
        super().__init__(**kwargs)
        self.reduction = reduction

    def build(self, input_shape):
        C = input_shape[-1]
        self._C = C
        r = max(C // self.reduction, 4)
        self.fc1 = Dense(r, activation='relu', use_bias=False, dtype='float32')
        self.fc2 = Dense(C, activation='sigmoid', use_bias=False, dtype='float32')
        super().build(input_shape)

    def call(self, x, training=False):
        # Use keras.ops instead of tf.* for Keras 3 compatibility
        x_f32 = ops.cast(x, 'float32')
        gap = ops.mean(x_f32, axis=[1, 2])           # (B, C)
        attn = self.fc1(gap)
        attn = self.fc2(attn)                         # (B, C)
        attn = ops.expand_dims(attn, axis=1)          # (B, 1, C)
        attn = ops.expand_dims(attn, axis=1)          # (B, 1, 1, C)
        out = x_f32 * attn
        return ops.cast(out, x.dtype)

    def get_config(self):
        cfg = super().get_config()
        cfg['reduction'] = self.reduction
        return cfg


class ScaleAwareFusion(Layer):
    """Scale-Aware Fusion Gate (Keras 3 compatible).
    
    Novel: content-dependent learnable scale weighting.
    """
    def __init__(self, feat_dim=256, **kwargs):
        super().__init__(**kwargs)
        self.feat_dim = feat_dim

    def build(self, input_shape):
        self.proj_local = Dense(self.feat_dim, use_bias=False, dtype='float32',
                                name=f'{self.name}_proj_local')
        self.proj_semantic = Dense(self.feat_dim, use_bias=False, dtype='float32',
                                   name=f'{self.name}_proj_semantic')
        self.gate = Dense(2, activation='softmax', dtype='float32',
                          name=f'{self.name}_gate')
        self.bn = BatchNormalization(dtype='float32', name=f'{self.name}_bn')
        super().build(input_shape)

    def call(self, inputs, training=False):
        local_feat, semantic_feat = inputs
        local_feat = ops.cast(local_feat, 'float32')
        semantic_feat = ops.cast(semantic_feat, 'float32')

        local_proj = self.proj_local(local_feat)          # (B, feat_dim)
        semantic_proj = self.proj_semantic(semantic_feat)  # (B, feat_dim)

        gate_input = ops.concatenate([local_proj, semantic_proj], axis=-1)
        scale_weights = self.gate(gate_input)             # (B, 2)

        w_local = scale_weights[:, 0:1]       # (B, 1)
        w_semantic = scale_weights[:, 1:2]    # (B, 1)

        fused = w_local * local_proj + w_semantic * semantic_proj
        fused = self.bn(fused, training=training)
        return fused

    def get_config(self):
        cfg = super().get_config()
        cfg['feat_dim'] = self.feat_dim
        return cfg


class CastToFloat32(Layer):
    """Simple layer to cast tensor to float32 (Keras 3 Functional API safe)."""
    def call(self, x):
        return ops.cast(x, 'float32')


def build_mscaf_classifier(input_shape, num_classes, feat_dim=256,
                            se_reduction=8, dropout_rate=0.4):
    """Build full MS-CAF model using Functional API (Keras 3 compatible).

    NO tf.* ops on KerasTensors. All ops via layers or keras.ops inside layers.
    """
    backbone_multi, backbone_base = build_backbone_multiscale(input_shape)

    inputs = Input(shape=input_shape, name='input_image')

    # Multi-scale features (don't pass training= during graph construction!)
    local_map, semantic_map = backbone_multi(inputs)

    # SE attention on spatial maps
    local_attended = SEAttention(reduction=se_reduction, name='se_local')(local_map)
    semantic_attended = SEAttention(reduction=se_reduction, name='se_semantic')(semantic_map)

    # GAP → vectors
    local_feat = GlobalAveragePooling2D(name='gap_local')(local_attended)
    semantic_feat = GlobalAveragePooling2D(name='gap_semantic')(semantic_attended)

    # Scale-Aware Fusion
    fused = ScaleAwareFusion(feat_dim=feat_dim, name='fusion')(
        [local_feat, semantic_feat])

    # Classification Head
    x = BatchNormalization(name='head_bn')(fused)
    x = Dense(feat_dim, activation='relu', kernel_regularizer=l2(1e-4), name='head_dense')(x)
    x = Dropout(dropout_rate, name='head_dropout')(x)
    # Cast via Layer (not tf.cast!) for mixed precision
    x = CastToFloat32(name='cast_f32')(x)
    predictions = Dense(num_classes, activation='softmax', dtype='float32',
                        name='predictions')(x)

    model = Model(inputs=inputs, outputs=predictions, name='MSCAF_Model')
    return model, backbone_base


print("✅ MS-CAF Architecture v2 (Keras 3 compatible):")
print("   - All ops use keras.ops (no tf.* on KerasTensors)")
print("   - CastToFloat32 Layer instead of tf.cast()")
print("   - No training=True during graph construction")
print("   - TRUE multi-scale: block5 + block7")
# Out:
# ✅ MS-CAF Architecture v2 (Keras 3 compatible):
#    - All ops use keras.ops (no tf.* on KerasTensors)
#    - CastToFloat32 Layer instead of tf.cast()
#    - No training=True during graph construction
#    - TRUE multi-scale: block5 + block7

# %%
# ============================================================================
# CELL 4: LOSS FUNCTION — Class-Balanced Focal Loss
# ============================================================================
# Simplified: chỉ dùng CB Focal Loss cho classification.
# SupCon sẽ được thêm dưới dạng auxiliary regularization (optional phase 2).
#
# Lý do bỏ SupCon joint training:
#   - Custom train_step + Keras 3 = broken loss tracking
#   - SupCon cần batch lớn (>=64) để có đủ positives, batch=16 quá nhỏ
#   - MS-CAF + CB Focal đã đủ mạnh, test trước rồi thêm SupCon sau
# ============================================================================


class ClassBalancedFocalLoss(tf.keras.losses.Loss):
    """Class-Balanced Focal Loss.
    
    CB weights (Cui et al., CVPR 2019): effective number of samples
    Focal (Lin et al., ICCV 2017): down-weight easy examples
    
    Combined: handles both class imbalance AND easy/hard example imbalance.
    """
    def __init__(self, samples_per_class, num_classes, gamma=2.0, beta=0.9999, label_smoothing=0.0, **kwargs):
        super().__init__(**kwargs)
        self.gamma = gamma
        self.beta = beta
        self.num_classes = num_classes
        self.label_smoothing = float(label_smoothing)
        self._samples_per_class = list(samples_per_class)
        
        # Compute CB weights: w_i = (1-β) / (1-β^n_i), normalized
        n = np.array(samples_per_class, dtype=np.float32)
        eff_num = 1.0 - np.power(beta, n)
        weights = (1.0 - beta) / eff_num
        weights = weights / weights.sum() * num_classes
        self.cb_weights = tf.constant(weights, dtype=tf.float32)
        print(f"  CB weights: {dict(zip(range(num_classes), weights.round(4)))}")

    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_true_hard = y_true

        # Label smoothing to improve calibration/generalization
        if self.label_smoothing > 0.0:
            y_true = y_true * (1.0 - self.label_smoothing) + (self.label_smoothing / self.num_classes)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)
        
        # Per-sample class weight (use hard labels)
        sample_w = tf.reduce_sum(y_true_hard * self.cb_weights, axis=-1)
        
        # Focal modulation: (1 - p_t)^gamma
        pt = tf.reduce_sum(y_true * y_pred, axis=-1)
        focal = tf.pow(1.0 - pt, self.gamma)
        
        # Cross-entropy
        ce = -tf.reduce_sum(y_true * tf.math.log(y_pred), axis=-1)
        
        return tf.reduce_mean(sample_w * focal * ce)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'samples_per_class': self._samples_per_class,
                    'num_classes': self.num_classes,
                    'gamma': self.gamma, 'beta': self.beta,
                    'label_smoothing': self.label_smoothing})
        return cfg


print("✅ ClassBalancedFocalLoss defined (CB + Focal)")
print("   - No SupCon in this version (batch too small, loss tracking broken)")
print("   - Focus: MS-CAF architecture + CB Focal → clean comparison with FSDA")
# Out:
# ✅ ClassBalancedFocalLoss defined (CB + Focal)
#    - No SupCon in this version (batch too small, loss tracking broken)
#    - Focus: MS-CAF architecture + CB Focal → clean comparison with FSDA

# %%
# ============================================================================
# CELL 5: DATA PIPELINE
# ============================================================================
# Returns ONE-HOT labels (for standard Keras training, not integer labels)
# ============================================================================

efficientnet_preprocess = tf.keras.applications.efficientnet.preprocess_input

# Augmentation — moderate (dataset nhỏ cần aug nhưng không quá mạnh)
_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.08),
    tf.keras.layers.RandomZoom(0.15),
    tf.keras.layers.RandomTranslation(0.10, 0.10),
    tf.keras.layers.RandomBrightness(factor=0.15),
    tf.keras.layers.RandomContrast(factor=0.15),
], name='augmentation')


def _collect_samples(split_dir, class_to_idx):
    """Collect all image paths + labels from a split directory."""
    paths, labels, filenames = [], [], []
    for cn, ci in sorted(class_to_idx.items()):
        d = os.path.join(split_dir, cn)
        if not os.path.isdir(d):
            continue
        for fname in sorted(os.listdir(d)):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
                paths.append(os.path.join(d, fname))
                labels.append(ci)
                filenames.append(f"{cn}/{fname}")
    return paths, labels, filenames


def create_tf_datasets(data_dir, input_shape, batch_size, seed=None):
    """Create train/val/test tf.data.Dataset pipelines (ONE-HOT labels)."""
    class_names = sorted([d for d in os.listdir(os.path.join(data_dir, 'train'))
                          if os.path.isdir(os.path.join(data_dir, 'train', d))])
    class_to_idx = {cn: i for i, cn in enumerate(class_names)}
    num_classes = len(class_names)
    h, w = input_shape[:2]

    def load_and_preprocess(path, label):
        raw = tf.io.read_file(path)
        img = tf.image.decode_jpeg(raw, channels=3)
        img = tf.image.resize(img, [h, w])
        img = tf.cast(img, tf.float32)
        img = efficientnet_preprocess(img)
        # Return ONE-HOT label (standard Keras)
        return img, tf.one_hot(label, depth=num_classes)

    def augment(img, lbl):
        return _augmentation(img, training=True), lbl

    def _make_split(split, training=False):
        sdir = os.path.join(data_dir, split)
        paths, labels, fns = _collect_samples(sdir, class_to_idx)
        ds = tf.data.Dataset.from_tensor_slices((paths, labels))
        if training:
            ds = ds.shuffle(len(paths), seed=seed, reshuffle_each_iteration=True)
        ds = ds.map(load_and_preprocess, num_parallel_calls=AUTOTUNE)
        if training:
            ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
        ds = ds.batch(batch_size, drop_remainder=training).prefetch(AUTOTUNE)
        return ds, len(paths), fns, labels

    train_ds, n_train, _, train_lbl = _make_split('train', training=True)
    val_ds, n_val, _, _ = _make_split('val', training=False)
    test_ds, n_test, test_fnames, test_lbl = _make_split('test', training=False)

    # Samples per class for CB loss
    samples_per_class = [train_lbl.count(i) for i in range(num_classes)]
    
    meta = SimpleNamespace(
        class_names=class_names, num_classes=num_classes,
        test_filenames=test_fnames, test_classes=np.array(test_lbl),
        n_train=n_train, n_val=n_val, n_test=n_test,
        samples_per_class=samples_per_class,
    )
    print(f"  Data: train={n_train} val={n_val} test={n_test}")
    print(f"  Classes: {class_names}")
    print(f"  Samples/class (train): {samples_per_class}")
    return train_ds, val_ds, test_ds, meta


print("✅ Data pipeline defined (one-hot labels for standard Keras training).")
# Out:
# ✅ Data pipeline defined (one-hot labels for standard Keras training).
# I0000 00:00:1779192578.714910      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1779192578.721116      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
# ============================================================================
# CELL 6: MODEL BUILDER (Functional API — FIXED)
# ============================================================================
# Dùng model.compile(loss=...) bình thường → Keras track loss đúng
# → EarlyStopping/ModelCheckpoint hoạt động chính xác
# ============================================================================


def apply_freeze_strategy(base_model, unfreeze_blocks):
    """Freeze backbone except specified blocks. Keep BN frozen."""
    base_model.trainable = False
    for layer in base_model.layers:
        for block_num in unfreeze_blocks:
            if layer.name.startswith(f"block{block_num}"):
                if not isinstance(layer, tf.keras.layers.BatchNormalization):
                    layer.trainable = True
                break
    trainable = sum(1 for l in base_model.layers if l.trainable)
    total = len(base_model.layers)
    print(f"  Backbone: {trainable}/{total} layers trainable")


def build_and_compile_model(num_classes, samples_per_class, steps_per_epoch):
    """Build, freeze, and compile the MS-CAF model.
    
    Uses standard Keras compile → loss tracking works → callbacks work.
    """
    # Build model
    model, backbone_base = build_mscaf_classifier(
        input_shape=INPUT_SHAPE,
        num_classes=num_classes,
        feat_dim=FEAT_DIM,
        se_reduction=SE_REDUCTION,
        dropout_rate=DROPOUT_RATE,
    )
    
    # Freeze strategy on backbone
    apply_freeze_strategy(backbone_base, UNFREEZE_BLOCKS)
    
    # Loss function
    loss_fn = ClassBalancedFocalLoss(
        samples_per_class=samples_per_class,
        num_classes=num_classes,
        gamma=FOCAL_GAMMA,
        beta=0.9999,
        label_smoothing=LABEL_SMOOTHING,
    )
    
    # Optimizer with cosine decay
    total_steps = steps_per_epoch * EPOCHS
    lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=LR,
        decay_steps=total_steps,
        alpha=1e-6,
    )
    optimizer = tf.keras.optimizers.AdamW(
        learning_rate=lr_schedule,
        weight_decay=WEIGHT_DECAY,
        clipnorm=1.0,
    )

    auc_metric = tf.keras.metrics.AUC(
        name='auc_ovr',
        curve='ROC',
        multi_label=True,
        num_labels=num_classes,
    )

    # Standard compile — Keras WILL track loss correctly
    model.compile(
        optimizer=optimizer,
        loss=loss_fn,
        metrics=['accuracy', auc_metric],
    )
    
    print(f"  Model params: {model.count_params():,}")
    return model


print("✅ Model builder (Functional API + standard compile)")
print("   - Keras loss tracking: ✅ WORKS")
print("   - EarlyStopping on val_auc_ovr: ✅ WORKS")
print("   - CosineDecay LR schedule")
# Out:
# ✅ Model builder (Functional API + standard compile)
#    - Keras loss tracking: ✅ WORKS
#    - EarlyStopping on val_loss: ✅ WORKS
#    - CosineDecay LR schedule

# %%
# ============================================================================
# CELL 7: MULTI-RUN TRAINING LOOP
# ============================================================================

def predict_with_tta(model, ds, tta_rounds=0):
    """Average predictions from original + random TTA passes.

    The augmentation pipeline was built on per-image tensors (H, W, C),
    so apply it image-by-image inside each batch for TTA.
    """
    probs = model.predict(ds, verbose=0)
    if tta_rounds <= 0:
        return probs

    probs_sum = probs.astype(np.float32)
    for _ in range(tta_rounds):
        aug_probs = []
        for batch_x, _ in ds:
            batch_aug = tf.map_fn(
                lambda img: _augmentation(img, training=True),
                batch_x,
                fn_output_signature=tf.TensorSpec(shape=batch_x.shape[1:], dtype=batch_x.dtype),
            )
            aug_probs.append(model(batch_aug, training=False).numpy().astype(np.float32))
        probs_sum += np.concatenate(aug_probs, axis=0)
    return probs_sum / float(tta_rounds + 1)

for run_idx, seed in enumerate(RANDOM_SEEDS[:N_RUNS]):
    print("\n" + "=" * 70)
    print(f" RUN {run_idx+1}/{N_RUNS}  seed={seed}  |  {STRATEGY_LABEL}")
    print("=" * 70)

    # --- Reproducibility ---
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
    RESULT_DIR = os.path.join(BASE_RESULT_DIR, f"run_{run_idx+1}_seed_{seed}")
    os.makedirs(RESULT_DIR, exist_ok=True)

    # --- Data ---
    train_ds, val_ds, test_ds, meta = create_tf_datasets(
        DATA_DIR, INPUT_SHAPE, BATCH_SIZE, seed=seed)
    steps_per_epoch = meta.n_train // BATCH_SIZE

    # --- Build Model ---
    model = build_and_compile_model(
        num_classes=meta.num_classes,
        samples_per_class=meta.samples_per_class,
        steps_per_epoch=steps_per_epoch,
    )

    if run_idx == 0:
        print(f"\n  Model architecture:")
        print(f"    Backbone: EfficientNetB4 (unfreeze {UNFREEZE_BLOCKS})")
        print(f"    MS-CAF: SE(r={SE_REDUCTION}) on spatial maps + Scale Fusion → {FEAT_DIM}D")
        print(f"    Classifier: BN→Dense({FEAT_DIM})→Dropout({DROPOUT_RATE})→Softmax({meta.num_classes})")
        print(f"    Loss: CB Focal (γ={FOCAL_GAMMA})")
        print(f"    LR: CosineDecay({LR} → 1e-6)")

    # --- Callbacks ---
    callbacks = [
        EarlyStopping(
            monitor='val_auc_ovr', mode='max', patience=PATIENCE,
            restore_best_weights=True, verbose=1),
        CSVLogger(os.path.join(RESULT_DIR, 'training_log.csv')),
        ModelCheckpoint(
            os.path.join(RESULT_DIR, 'best_model.keras'),
            save_best_only=True, monitor='val_auc_ovr', mode='max', verbose=1),
    ]

    # --- Train (standard Keras fit — loss tracking works!) ---
    history = model.fit(
        train_ds, validation_data=val_ds,
        epochs=EPOCHS, callbacks=callbacks,
    )

    # --- Evaluate on Test ---
    pred_probs = predict_with_tta(model, test_ds, tta_rounds=TTA_ROUNDS)
    y_pred_run = np.argmax(pred_probs, axis=1)
    y_true_run = meta.test_classes

    report = classification_report(
        y_true_run, y_pred_run,
        target_names=meta.class_names, output_dict=True, digits=4)
    test_acc = np.mean(y_pred_run == y_true_run)

    # --- Multiclass AUC (OvR) ---
    y_true_onehot = label_binarize(y_true_run, classes=np.arange(meta.num_classes))
    try:
        test_auc_macro = roc_auc_score(
            y_true_onehot, pred_probs,
            average='macro', multi_class='ovr'
        )
        test_auc_weighted = roc_auc_score(
            y_true_onehot, pred_probs,
            average='weighted', multi_class='ovr'
        )
    except ValueError:
        test_auc_macro = np.nan
        test_auc_weighted = np.nan

    # --- Save Artifacts ---
    with open(os.path.join(RESULT_DIR, 'classification_report.txt'), 'w') as f:
        f.write(classification_report(
            y_true_run, y_pred_run,
            target_names=meta.class_names, digits=4))

    # Confusion matrix
    cm = confusion_matrix(y_true_run, y_pred_run)
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=meta.class_names,
                yticklabels=meta.class_names, cmap='Blues', ax=ax)
    ax.set_title(f'Confusion Matrix — Run {run_idx+1} (Acc={test_acc:.4f})')
    plt.tight_layout()
    plt.savefig(os.path.join(RESULT_DIR, 'confusion_matrix.png'), dpi=300)
    plt.close()

    # ROC curves (OvR)
    fig, ax = plt.subplots(figsize=(8, 6))
    for ci, cname in enumerate(meta.class_names):
        fpr, tpr, _ = roc_curve(y_true_onehot[:, ci], pred_probs[:, ci])
        class_auc = auc(fpr, tpr)
        ax.plot(fpr, tpr, lw=2, label=f"{cname} (AUC={class_auc:.4f})")
    ax.plot([0, 1], [0, 1], 'k--', lw=1)
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'ROC Curves OvR — Run {run_idx+1} (macro AUC={test_auc_macro:.4f})')
    ax.legend(loc='lower right', fontsize=9)
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(os.path.join(RESULT_DIR, 'roc_curves_ovr.png'), dpi=300)
    plt.close()

    # Learning curves
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    hist = history.history
    axes[0].plot(hist['loss'], label='Train')
    axes[0].plot(hist['val_loss'], label='Val')
    axes[0].set_title('Loss (CB Focal)')
    axes[0].legend(); axes[0].grid(alpha=0.3)
    
    axes[1].plot(hist['accuracy'], label='Train')
    axes[1].plot(hist['val_accuracy'], label='Val')
    axes[1].set_title('Accuracy')
    axes[1].legend(); axes[1].grid(alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(os.path.join(RESULT_DIR, 'learning_curves.png'), dpi=300)
    plt.close()

    # Store results
    all_runs_results.append({
        'run': run_idx+1, 'seed': seed,
        'accuracy': test_acc,
        'precision': report['weighted avg']['precision'],
        'recall': report['weighted avg']['recall'],
        'f1_score': report['weighted avg']['f1-score'],
        'auc_ovr_macro': test_auc_macro,
        'auc_ovr_weighted': test_auc_weighted,
        'per_class_metrics': {c: report[c] for c in meta.class_names},
        'result_dir': RESULT_DIR,
        'history': history.history,
        'y_true': y_true_run, 'y_pred': y_pred_run,
        'pred_probs': pred_probs,
        'class_names': meta.class_names,
        'test_filenames': meta.test_filenames,
    })

    print(f"\n  ✅ Run {run_idx+1} Results:")
    print(f"     Acc={test_acc:.4f}  P={report['weighted avg']['precision']:.4f}  "
          f"R={report['weighted avg']['recall']:.4f}  F1={report['weighted avg']['f1-score']:.4f}")
    print(f"     AUC_macro(OvR)={test_auc_macro:.4f}  AUC_weighted(OvR)={test_auc_weighted:.4f}")
    
    # Cleanup
    tf.keras.backend.clear_session()
    gc.collect()

print("\n" + "=" * 70)
print(f" ALL {N_RUNS} RUNS COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
#  RUN 1/3  seed=42  |  EfficientNetB4 + MS-CAF v2 (Multi-Scale Channel-Attention Fusion)
# ======================================================================
#   Data: train=1492 val=318 test=324
#   Classes: ['Fully_Peeled_Garlic', 'Partially_Peeled_Garlic', 'Spoiled_Garlic']
#   Samples/class (train): [482, 306, 704]
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#   Multi-scale outputs:
#     Local  : block5f_add → (None, 24, 24, 160)
#     Semantic: final output → (None, 12, 12, 1792)
#   Backbone: 305/475 layers trainable
#   CB weights: {0: np.float32(0.922), 1: np.float32(1.4397), 2: np.float32(0.6383)}
#   Model params: 19,052,388
#
#   Model architecture:
#     Backbone: EfficientNetB4 (unfreeze [3, 4, 5, 6, 7])
#     MS-CAF: SE(r=8) on spatial maps + Scale Fusion → 256D
#     Classifier: BN→Dense(256)→Dropout(0.3)→Softmax(3)
#     Loss: CB Focal (γ=2.0)
#     LR: CosineDecay(0.0001 → 1e-6)
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779192609.725824     132 service.cc:152] XLA service 0x7f87680266a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779192609.725886     132 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779192609.725894     132 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779192609.795106     132 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1779192610.057153     132 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-05-19 12:11:35.054377: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.81 = (f16[192,5,5,1]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,95,95,192]{3,2,1,0} %bitcast.141078, f16[32,48,48,192]{3,2,1,0} %bitcast.141080), window={size=5x5 stride=2x2 pad=2_2x2_2}, dim_labels=b01f_o01i->b01f, feature_group_count=192, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="DepthwiseConv2dNativeBackpropFilter" op_name="gradient_tape/MSCAF_Model_1/efficientnetb4_multiscale_1/block3a_dwconv_1/depthwise/DepthwiseConv2dNativeBackpropFilter" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-05-19 12:11:35.454764: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.400482775s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.81 = (f16[192,5,5,1]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,95,95,192]{3,2,1,0} %bitcast.141078, f16[32,48,48,192]{3,2,1,0} %bitcast.141080), window={size=5x5 stride=2x2 pad=2_2x2_2}, dim_labels=b01f_o01i->b01f, feature_group_count=192, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="DepthwiseConv2dNativeBackpropFilter" op_name="gradient_tape/MSCAF_Model_1/efficientnetb4_multiscale_1/block3a_dwconv_1/depthwise/DepthwiseConv2dNativeBackpropFilter" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-05-19 12:11:40.599884: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:11:40.764764: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:11:52.773944: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:11:52.920328: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:11:57.722172: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:11:57.884768: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:12:06.462753: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:12:06.622109: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:12:06.861479: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:12:07.068986: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5986 - loss: 0.4344
# Epoch 1: val_loss improved from inf to 0.18764, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 399s 3s/step - accuracy: 0.6013 - loss: 0.4311 - val_accuracy: 0.8868 - val_loss: 0.1876
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8918 - loss: 0.1175
# Epoch 2: val_loss improved from 0.18764 to 0.14458, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8917 - loss: 0.1176 - val_accuracy: 0.8931 - val_loss: 0.1446
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9037 - loss: 0.1008
# Epoch 3: val_loss improved from 0.14458 to 0.12843, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.9037 - loss: 0.1009 - val_accuracy: 0.8836 - val_loss: 0.1284
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9320 - loss: 0.0810
# Epoch 4: val_loss improved from 0.12843 to 0.10765, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.9320 - loss: 0.0808 - val_accuracy: 0.8868 - val_loss: 0.1077
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9454 - loss: 0.0729
# Epoch 5: val_loss improved from 0.10765 to 0.08738, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9452 - loss: 0.0732 - val_accuracy: 0.8931 - val_loss: 0.0874
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9304 - loss: 0.0683
# Epoch 6: val_loss improved from 0.08738 to 0.08224, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9305 - loss: 0.0683 - val_accuracy: 0.9151 - val_loss: 0.0822
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9460 - loss: 0.0574
# Epoch 7: val_loss improved from 0.08224 to 0.07629, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9460 - loss: 0.0576 - val_accuracy: 0.9214 - val_loss: 0.0763
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9516 - loss: 0.0564
# Epoch 8: val_loss did not improve from 0.07629
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9515 - loss: 0.0565 - val_accuracy: 0.8899 - val_loss: 0.1033
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9502 - loss: 0.0634
# Epoch 9: val_loss did not improve from 0.07629
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9502 - loss: 0.0634 - val_accuracy: 0.9151 - val_loss: 0.0799
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9607 - loss: 0.0566
# Epoch 10: val_loss did not improve from 0.07629
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9607 - loss: 0.0566 - val_accuracy: 0.8994 - val_loss: 0.0863
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9529 - loss: 0.0629
# Epoch 11: val_loss improved from 0.07629 to 0.07614, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9529 - loss: 0.0629 - val_accuracy: 0.9057 - val_loss: 0.0761
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9770 - loss: 0.0445
# Epoch 12: val_loss improved from 0.07614 to 0.07147, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.9768 - loss: 0.0446 - val_accuracy: 0.9245 - val_loss: 0.0715
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9699 - loss: 0.0502
# Epoch 13: val_loss did not improve from 0.07147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9699 - loss: 0.0501 - val_accuracy: 0.9277 - val_loss: 0.0804
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9635 - loss: 0.0476
# Epoch 14: val_loss did not improve from 0.07147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9636 - loss: 0.0475 - val_accuracy: 0.9277 - val_loss: 0.0729
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9684 - loss: 0.0478
# Epoch 15: val_loss improved from 0.07147 to 0.06909, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_1_seed_42/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9685 - loss: 0.0477 - val_accuracy: 0.9277 - val_loss: 0.0691
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9736 - loss: 0.0373
# Epoch 16: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9736 - loss: 0.0373 - val_accuracy: 0.9277 - val_loss: 0.0806
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9814 - loss: 0.0369
# Epoch 17: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9814 - loss: 0.0369 - val_accuracy: 0.9277 - val_loss: 0.0810
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9774 - loss: 0.0384
# Epoch 18: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9774 - loss: 0.0385 - val_accuracy: 0.9119 - val_loss: 0.0789
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9862 - loss: 0.0340
# Epoch 19: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9861 - loss: 0.0341 - val_accuracy: 0.9371 - val_loss: 0.0694
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9822 - loss: 0.0339
# Epoch 20: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9822 - loss: 0.0339 - val_accuracy: 0.9277 - val_loss: 0.0819
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9912 - loss: 0.0316
# Epoch 21: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9911 - loss: 0.0316 - val_accuracy: 0.9403 - val_loss: 0.0785
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9880 - loss: 0.0313
# Epoch 22: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9880 - loss: 0.0314 - val_accuracy: 0.9245 - val_loss: 0.0829
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9888 - loss: 0.0325
# Epoch 23: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9887 - loss: 0.0326 - val_accuracy: 0.9371 - val_loss: 0.0786
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9840 - loss: 0.0363
# Epoch 24: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9841 - loss: 0.0362 - val_accuracy: 0.9371 - val_loss: 0.0775
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9937 - loss: 0.0307
# Epoch 25: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9937 - loss: 0.0307 - val_accuracy: 0.9371 - val_loss: 0.0792
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9942 - loss: 0.0298
# Epoch 26: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9942 - loss: 0.0298 - val_accuracy: 0.9371 - val_loss: 0.0810
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9893 - loss: 0.0313
# Epoch 27: val_loss did not improve from 0.06909
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9893 - loss: 0.0313 - val_accuracy: 0.9371 - val_loss: 0.0804
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 15.
#
#   ✅ Run 1 Results:
#      Acc=0.9383  P=0.9383  R=0.9383  F1=0.9383
#
# ======================================================================
#  RUN 2/3  seed=123  |  EfficientNetB4 + MS-CAF v2 (Multi-Scale Channel-Attention Fusion)
# ======================================================================
#   Data: train=1492 val=318 test=324
#   Classes: ['Fully_Peeled_Garlic', 'Partially_Peeled_Garlic', 'Spoiled_Garlic']
#   Samples/class (train): [482, 306, 704]
#   Multi-scale outputs:
#     Local  : block5f_add → (None, 24, 24, 160)
#     Semantic: final output → (None, 12, 12, 1792)
#   Backbone: 305/475 layers trainable
#   CB weights: {0: np.float32(0.922), 1: np.float32(1.4397), 2: np.float32(0.6383)}
#   Model params: 19,052,388
# Epoch 1/30
# 2026-05-19 12:40:33.242704: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:33.412168: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:33.785561: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:33.955149: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:34.591552: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:34.778817: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:35.494125: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:35.650195: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:36.626544: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:36.781902: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:38.428600: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:38.613603: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:40.876062: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:41.088711: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:46.187277: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:46.359336: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:49.035220: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:49.191600: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:49.347220: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:50.566762: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:50.710156: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:51.106767: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:40:51.293016: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6548 - loss: 0.4719
# 2026-05-19 12:42:58.172937: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:42:58.338624: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:42:58.716420: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:42:58.882119: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:42:59.429182: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:42:59.611008: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:43:00.239347: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:43:00.394649: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:43:01.334727: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:43:01.490442: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:43:02.965976: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 12:43:03.152525: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 0.17528, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_2_seed_123/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.6568 - loss: 0.4680 - val_accuracy: 0.8962 - val_loss: 0.1753
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8524 - loss: 0.1475
# Epoch 2: val_loss improved from 0.17528 to 0.12387, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_2_seed_123/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.8525 - loss: 0.1474 - val_accuracy: 0.9151 - val_loss: 0.1239
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8929 - loss: 0.1194
# Epoch 3: val_loss improved from 0.12387 to 0.10906, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_2_seed_123/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.8930 - loss: 0.1192 - val_accuracy: 0.8994 - val_loss: 0.1091
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9171 - loss: 0.0894
# Epoch 4: val_loss improved from 0.10906 to 0.09517, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_2_seed_123/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9169 - loss: 0.0895 - val_accuracy: 0.8931 - val_loss: 0.0952
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9249 - loss: 0.0905
# Epoch 5: val_loss did not improve from 0.09517
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9248 - loss: 0.0905 - val_accuracy: 0.8616 - val_loss: 0.1006
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9318 - loss: 0.0810
# Epoch 6: val_loss improved from 0.09517 to 0.07361, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_2_seed_123/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9318 - loss: 0.0811 - val_accuracy: 0.9119 - val_loss: 0.0736
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9328 - loss: 0.0680
# Epoch 7: val_loss improved from 0.07361 to 0.07056, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_2_seed_123/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9329 - loss: 0.0681 - val_accuracy: 0.9057 - val_loss: 0.0706
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9450 - loss: 0.0679
# Epoch 8: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9451 - loss: 0.0679 - val_accuracy: 0.9182 - val_loss: 0.0738
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9631 - loss: 0.0606
# Epoch 9: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9630 - loss: 0.0606 - val_accuracy: 0.9119 - val_loss: 0.0753
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9514 - loss: 0.0482
# Epoch 10: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9515 - loss: 0.0482 - val_accuracy: 0.9119 - val_loss: 0.0798
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9629 - loss: 0.0466
# Epoch 11: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9630 - loss: 0.0466 - val_accuracy: 0.8994 - val_loss: 0.1080
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9656 - loss: 0.0449
# Epoch 12: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9655 - loss: 0.0451 - val_accuracy: 0.9025 - val_loss: 0.0946
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9791 - loss: 0.0433
# Epoch 13: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9790 - loss: 0.0434 - val_accuracy: 0.9214 - val_loss: 0.0807
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9754 - loss: 0.0417
# Epoch 14: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9752 - loss: 0.0417 - val_accuracy: 0.9182 - val_loss: 0.0758
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9768 - loss: 0.0390
# Epoch 15: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9768 - loss: 0.0390 - val_accuracy: 0.9277 - val_loss: 0.0841
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9678 - loss: 0.0393
# Epoch 16: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9678 - loss: 0.0394 - val_accuracy: 0.9214 - val_loss: 0.0892
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9732 - loss: 0.0406
# Epoch 17: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9733 - loss: 0.0405 - val_accuracy: 0.9182 - val_loss: 0.0920
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9767 - loss: 0.0370
# Epoch 18: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9768 - loss: 0.0370 - val_accuracy: 0.9214 - val_loss: 0.0908
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9742 - loss: 0.0386
# Epoch 19: val_loss did not improve from 0.07056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9743 - loss: 0.0386 - val_accuracy: 0.9277 - val_loss: 0.0784
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 2026-05-19 13:04:58.415329: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:04:58.551813: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:04:58.791412: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:04:58.926696: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:04:59.170488: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:04:59.310380: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:04:59.657050: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:04:59.813490: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:05:00.665342: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:05:00.821326: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:05:01.790579: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-19 13:05:01.978298: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   ✅ Run 2 Results:
#      Acc=0.9321  P=0.9321  R=0.9321  F1=0.9320
#
# ======================================================================
#  RUN 3/3  seed=456  |  EfficientNetB4 + MS-CAF v2 (Multi-Scale Channel-Attention Fusion)
# ======================================================================
#   Data: train=1492 val=318 test=324
#   Classes: ['Fully_Peeled_Garlic', 'Partially_Peeled_Garlic', 'Spoiled_Garlic']
#   Samples/class (train): [482, 306, 704]
#   Multi-scale outputs:
#     Local  : block5f_add → (None, 24, 24, 160)
#     Semantic: final output → (None, 12, 12, 1792)
#   Backbone: 305/475 layers trainable
#   CB weights: {0: np.float32(0.922), 1: np.float32(1.4397), 2: np.float32(0.6383)}
#   Model params: 19,052,388
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5600 - loss: 0.4747
# Epoch 1: val_loss improved from inf to 0.21363, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_3_seed_456/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 186s 2s/step - accuracy: 0.5629 - loss: 0.4711 - val_accuracy: 0.7673 - val_loss: 0.2136
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8626 - loss: 0.1509
# Epoch 2: val_loss improved from 0.21363 to 0.12319, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_3_seed_456/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.8626 - loss: 0.1506 - val_accuracy: 0.8836 - val_loss: 0.1232
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8811 - loss: 0.1220
# Epoch 3: val_loss improved from 0.12319 to 0.10858, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_3_seed_456/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.8812 - loss: 0.1220 - val_accuracy: 0.8962 - val_loss: 0.1086
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9082 - loss: 0.1033
# Epoch 4: val_loss improved from 0.10858 to 0.09835, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_3_seed_456/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9083 - loss: 0.1030 - val_accuracy: 0.8899 - val_loss: 0.0984
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9167 - loss: 0.0826
# Epoch 5: val_loss improved from 0.09835 to 0.06820, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_3_seed_456/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9168 - loss: 0.0826 - val_accuracy: 0.9088 - val_loss: 0.0682
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9426 - loss: 0.0640
# Epoch 6: val_loss improved from 0.06820 to 0.06515, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_3_seed_456/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9425 - loss: 0.0642 - val_accuracy: 0.9182 - val_loss: 0.0651
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9497 - loss: 0.0653
# Epoch 7: val_loss did not improve from 0.06515
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9497 - loss: 0.0653 - val_accuracy: 0.8553 - val_loss: 0.2725
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9582 - loss: 0.0538
# Epoch 8: val_loss did not improve from 0.06515
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9582 - loss: 0.0537 - val_accuracy: 0.9182 - val_loss: 0.0798
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9672 - loss: 0.0457
# Epoch 9: val_loss did not improve from 0.06515
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9671 - loss: 0.0457 - val_accuracy: 0.9245 - val_loss: 0.0701
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9741 - loss: 0.0445
# Epoch 10: val_loss improved from 0.06515 to 0.06413, saving model to /kaggle/working/report_EfficientNetB4/ms_caf_v2/run_3_seed_456/best_model.keras
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - accuracy: 0.9740 - loss: 0.0446 - val_accuracy: 0.9340 - val_loss: 0.0641
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9728 - loss: 0.0438
# Epoch 11: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9726 - loss: 0.0439 - val_accuracy: 0.9340 - val_loss: 0.0938
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9815 - loss: 0.0396
# Epoch 12: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9814 - loss: 0.0397 - val_accuracy: 0.9151 - val_loss: 0.0903
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9728 - loss: 0.0429
# Epoch 13: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9727 - loss: 0.0430 - val_accuracy: 0.9151 - val_loss: 0.0893
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9821 - loss: 0.0385
# Epoch 14: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9821 - loss: 0.0385 - val_accuracy: 0.9214 - val_loss: 0.0801
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9744 - loss: 0.0407
# Epoch 15: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9744 - loss: 0.0407 - val_accuracy: 0.9182 - val_loss: 0.0834
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9774 - loss: 0.0376
# Epoch 16: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9774 - loss: 0.0376 - val_accuracy: 0.9340 - val_loss: 0.0711
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9826 - loss: 0.0364
# Epoch 17: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9826 - loss: 0.0364 - val_accuracy: 0.9340 - val_loss: 0.0951
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9826 - loss: 0.0334
# Epoch 18: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9826 - loss: 0.0335 - val_accuracy: 0.9308 - val_loss: 0.0966
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9738 - loss: 0.0390
# Epoch 19: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9740 - loss: 0.0389 - val_accuracy: 0.9182 - val_loss: 0.0849
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9873 - loss: 0.0345
# Epoch 20: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9872 - loss: 0.0345 - val_accuracy: 0.9245 - val_loss: 0.0845
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9890 - loss: 0.0353
# Epoch 21: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9889 - loss: 0.0353 - val_accuracy: 0.9277 - val_loss: 0.0860
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9917 - loss: 0.0311
# Epoch 22: val_loss did not improve from 0.06413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9917 - loss: 0.0311 - val_accuracy: 0.9277 - val_loss: 0.0862
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
#   ✅ Run 3 Results:
#      Acc=0.9290  P=0.9293  R=0.9290  F1=0.9291
#
# ======================================================================
#  ALL 3 RUNS COMPLETED
# ======================================================================

# %%
# ============================================================================
# CELL 8: RESULTS AGGREGATION & COMPARISON
# ============================================================================

accuracies  = [r['accuracy'] for r in all_runs_results]
precisions  = [r['precision'] for r in all_runs_results]
recalls     = [r['recall'] for r in all_runs_results]
f1_scores   = [r['f1_score'] for r in all_runs_results]
auc_macro  = [r['auc_ovr_macro'] for r in all_runs_results]
auc_weight = [r['auc_ovr_weighted'] for r in all_runs_results]

print(f"\n{'=' * 60}")
print(f"  {STRATEGY_LABEL}")
print(f"{'=' * 60}")
print(f"  Accuracy  : {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"  Precision : {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"  Recall    : {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"  F1-Score  : {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"  AUC macro : {np.mean(auc_macro):.4f} ± {np.std(auc_macro):.4f}")
print(f"  AUC w-avg : {np.mean(auc_weight):.4f} ± {np.std(auc_weight):.4f}")
print(f"  Per run acc: {[f'{a:.4f}' for a in accuracies]}")

print("\n  Additional Metrics:")
for r in all_runs_results:
    kappa = cohen_kappa_score(r['y_true'], r['y_pred'])
    mcc = matthews_corrcoef(r['y_true'], r['y_pred'])
    bal_acc = balanced_accuracy_score(r['y_true'], r['y_pred'])
    print(f"    Run {r['run']}: BalAcc={bal_acc:.4f}  Kappa={kappa:.4f}  MCC={mcc:.4f}  AUC={r['auc_ovr_macro']:.4f}")

# Per-class breakdown
class_names = all_runs_results[0]['class_names']
print("\n  PER-CLASS METRICS (mean ± std):")
print("  " + "-" * 68)
for cn in class_names:
    p_vals = [r['per_class_metrics'][cn]['precision'] for r in all_runs_results]
    r_vals = [r['per_class_metrics'][cn]['recall'] for r in all_runs_results]
    f_vals = [r['per_class_metrics'][cn]['f1-score'] for r in all_runs_results]
    print(f"    {cn:<28} P={np.mean(p_vals):.4f}±{np.std(p_vals):.4f}  "
          f"R={np.mean(r_vals):.4f}±{np.std(r_vals):.4f}  "
          f"F1={np.mean(f_vals):.4f}±{np.std(f_vals):.4f}")

# Comparison with baseline
print("\n" + "=" * 60)
print("  COMPARISON WITH BASELINE")
print("=" * 60)
baseline_acc = 0.92  # Baseline FSDA accuracy
proposed_acc = np.mean(accuracies)
diff = proposed_acc - baseline_acc
print(f"  Baseline (FSDA)    : ~{baseline_acc:.4f}")
print(f"  Proposed (MS-CAF)  : {proposed_acc:.4f} ± {np.std(accuracies):.4f}")
print(f"  Difference         : {diff:+.4f} ({'↑ IMPROVED' if diff > 0 else '↓ Need tuning'})")

# Save summary
summary_df = pd.DataFrame([{
    'strategy': STRATEGY_KEY, 'run': r['run'], 'seed': r['seed'],
    'accuracy': r['accuracy'], 'precision': r['precision'],
    'recall': r['recall'], 'f1_score': r['f1_score'],
    'auc_ovr_macro': r['auc_ovr_macro'], 'auc_ovr_weighted': r['auc_ovr_weighted'],
} for r in all_runs_results])
summary_df.to_csv(os.path.join(BASE_RESULT_DIR, 'summary.csv'), index=False)

# Zip results
zip_path = f"/kaggle/working/{STRATEGY_KEY}_complete"
shutil.make_archive(zip_path, 'zip', BASE_RESULT_DIR)
print(f"\n  ✅ Archived → {zip_path}.zip")
# Out:
# ============================================================
#   EfficientNetB4 + MS-CAF v2 (Multi-Scale Channel-Attention Fusion)
# ============================================================
#   Accuracy  : 0.9331 ± 0.0038
#   Precision : 0.9332 ± 0.0038
#   Recall    : 0.9331 ± 0.0038
#   F1-Score  : 0.9331 ± 0.0038
#   Per run acc: ['0.9383', '0.9321', '0.9290']
#
#   Additional Metrics:
#     Run 1: BalAcc=0.9381  Kappa=0.9023  MCC=0.9023
#     Run 2: BalAcc=0.9364  Kappa=0.8928  MCC=0.8929
#     Run 3: BalAcc=0.9286  Kappa=0.8874  MCC=0.8875
#
#   PER-CLASS METRICS (mean ± std):
#   --------------------------------------------------------------------
#     Fully_Peeled_Garlic          P=0.9232±0.0130  R=0.9143±0.0135  F1=0.9187±0.0117
#     Partially_Peeled_Garlic      P=0.9460±0.0171  R=0.9502±0.0141  F1=0.9479±0.0059
#     Spoiled_Garlic               P=0.9345±0.0050  R=0.9386±0.0031  F1=0.9365±0.0030
#
# ============================================================
#   COMPARISON WITH BASELINE
# ============================================================
#   Baseline (FSDA)    : ~0.9200
#   Proposed (MS-CAF)  : 0.9331 ± 0.0038
#   Difference         : +0.0131 (↑ IMPROVED)
#
#   ✅ Archived → /kaggle/working/ms_caf_v2_complete.zip
